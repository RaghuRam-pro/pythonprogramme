# %% [markdown]
# <a href="https://colab.research.google.com/github/RaghuRam-pro/pythonprogramme/blob/main/Week1/week1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## adding two numbers

# %%
print(9+9)
# Out:
# 18

# %%
a=9
print(type(a))
# Out:
# <class 'int'>

# %%
a='RAGHU'
print(type(a))
# Out:
# <class 'str'>

# %%
print('1+2')
print(1+2)
# Out:
# 1+2
# 3

# %% [markdown]
# ## INPUTS

# %%
a=input()
b=int(input())
# Out:
# hii
# 3

# %% [markdown]
# ##ARTHIMETIC OPERATIONS

# %%
 a=int(input("enter any number"))
 b=int(input("enter any number"))
 print(a+b)
 print(a-b)
 print(a*b)
 print(a/b)
 print(a//b)
 print(a%b)
 print(a**b)
# Out:
# enter any number2
# enter any number3
# 5
# -1
# 6
# 0.6666666666666666
# 0
# 2
# 8
